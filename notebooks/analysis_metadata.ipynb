# %%
# %load_ext lab_black

# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\neuro-closeloop-project\\vielight_close_loop\\metadata.csv")
df.head()
# Out:
#     stage  stage_no  patient  condition_number  \
# 0     pre         1        2                 1
# 1     pre         1        2                 1
# 2  during         2        2                 1
# 3    post         3        2                 1
# 4    post         3        2                 1
#
#                                filename  \
# 0   MED_PBM_002_Cond1_COG_PRE_RELAX.fdt
# 1       MED_PBM_002_Cond1_PRE_RELAX.fdt
# 2    MED_PBM_002_Cond1_DURING_RELAX.fdt
# 3  MED_PBM_002_Cond1_COG_POST_RELAX.fdt
# 4      MED_PBM_002_Cond1_POST_RELAX.fdt
#
#                                             channels  n_channels  duration  \
# 0  ['AF3', 'AF4', 'C1', 'C2', 'C3', 'C4', 'C5', '...          60   552.999
# 1  ['AF3', 'AF4', 'C1', 'C2', 'C3', 'C4', 'C5', '...          60   248.999
# 2  ['AF3', 'AF4', 'C1', 'C2', 'C3', 'C4', 'C5', '...          60  1099.499
# 3  ['AF3', 'AF4', 'C1', 'C2', 'C3', 'C4', 'C5', '...          60   564.499
# ...
