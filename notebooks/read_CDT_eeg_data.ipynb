# %%
import mne
import os

# %%
data_path = "D:\\preprocessing-happie\\HAPPE-master\\HAPPE-master\\datasets\\raw_dataset"

# Replace with your actual .cdt filename (and path if needed):
filename = os.path.join(data_path, 'MED2_S01_during_V1.cdt')

# MNE will look for the matching sidecar files (.ceo, .dpo, etc.) automatically
raw = mne.io.read_raw_curry(filename, preload=True)

# Now you can inspect basic info:
print(raw.info)
# And even plot the raw EEG:
raw.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 filename = os.path.join(data_path, 'MED2_S01_during_V1.cdt')
#       6 # MNE will look for the matching sidecar files (.ceo, .dpo, etc.) automatically
# ----> 7 raw = mne.io.read_raw_curry(filename, preload=True)
#       9 # Now you can inspect basic info:
#      10 print(raw.info)
#
# File <decorator-gen-203>:12, in read_raw_curry(fname, preload, verbose)
#
# File d:\neuro-closeloop-project\vielight_close_loop\.venv\Lib\site-packages\mne\io\curry\curry.py:566, in read_raw_curry(fname, preload, verbose)
#     544 @verbose
#     545 def read_raw_curry(fname, preload=False, verbose=None) -> "RawCurry":
#     546     """Read raw data from Curry files.
#     547
#     548     Parameters
#    (...)
#     564     mne.io.Raw : Documentation of attributes and methods of RawCurry.
#     565     """
# ...
