# %%
import os
import glob

# %%
data_loc = "D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess"
eeg_files = glob.glob(os.path.join(data_loc, "*.mat"))
eeg_files
# Out:
# ['D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess\\MED2_S01_during2_V1_processed.mat',
#  'D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess\\MED2_S01_during_V1_processed.mat',
#  'D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess\\MED2_S01_EC1_V1_processed.mat',
#  'D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess\\MED2_S01_EC2_V1_processed.mat',
#  'D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess\\MED2_S01_OB1_V1_processed.mat',
#  'D:\\neuro-closeloop-project\\vielight_close_loop\\data\\happie_preprocess\\MED2_S01_OB2_V1_processed.mat']
